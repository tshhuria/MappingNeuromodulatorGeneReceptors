# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# File paths for your local files
file_paths = '/Users/tanmaysagarhuria/__MACOSX/FinalProject/2dcoordinates.csv'

# %%
def load_csv(file_path):
    try:
        df = pd.read_csv(file_path)
        print(f"Successfully loaded {file_path}")
        return df
    except Exception as e:
        print(f"Error loading {file_path}: {e}")
        return None

# %%
coordinates_df = load_csv(file_paths)
# Out:
# Successfully loaded /Users/tanmaysagarhuria/__MACOSX/FinalProject/2dcoordinates.csv

# %%
if coordinates_df is not None:
    print("Coordinates DataFrame:")
    print(coordinates_df.head())
# Out:
# Coordinates DataFrame:
#            sample_name     tsne_1     tsne_2
# 0  F2S4_160113_027_B01  32.150140   4.800442
# 1  F2S4_160113_027_C01  25.061348 -27.205498
# 2  F2S4_160113_027_D01  25.365039 -25.813437
# 3  F2S4_160113_027_E01  27.075344  13.713614
# 4  F2S4_160113_027_F01  27.660463   2.411001

# %%
# Inspect the structure of the DataFrame
print(coordinates_df.info())

# Display basic statistics for the DataFrame
print(coordinates_df.describe())

# Display the first few rows of the DataFrame
print(coordinates_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47432 entries, 0 to 47431
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sample_name  47432 non-null  object
#  1   tsne_1       47432 non-null  float64
#  2   tsne_2       47432 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 1.1+ MB
# None
#              tsne_1        tsne_2
# count  47432.000000  47432.000000
# mean      -0.010929      0.001802
# std       19.068450     19.478252
# min      -40.770907    -39.985468
# 25%      -14.450665    -14.781192
# 50%        0.373938      0.157918
# 75%       13.715118     13.432321
# max       44.827677     43.309449
#            sample_name     tsne_1     tsne_2
# 0  F2S4_160113_027_B01  32.150140   4.800442
# 1  F2S4_160113_027_C01  25.061348 -27.205498
# 2  F2S4_160113_027_D01  25.365039 -25.813437
# 3  F2S4_160113_027_E01  27.075344  13.713614
# 4  F2S4_160113_027_F01  27.660463   2.411001

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='tsne_1', y='tsne_2', data=coordinates_df, hue='sample_name', legend=None)
plt.title('t-SNE 2D Visualization')
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.show()

# %%
# Define the file path for metadata
file_path_metadata = '/Users/tanmaysagarhuria/__MACOSX/FinalProject/metadata.csv'

# Load the metadata CSV file
metadata_df = load_csv(file_path_metadata)
# Out:
# Successfully loaded /Users/tanmaysagarhuria/__MACOSX/FinalProject/metadata.csv

# %%
if metadata_df is not None:
    print("Metadata DataFrame:")
    print(metadata_df.info())
    print(metadata_df.describe())
    print(metadata_df.head())
# Out:
# Metadata DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49417 entries, 0 to 49416
# Data columns (total 41 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   sample_name                  49417 non-null  object
#  1   exp_component_name           49417 non-null  object
#  2   specimen_type                49417 non-null  object
#  3   cluster_color                47432 non-null  object
#  4   cluster_order                47432 non-null  float64
#  5   cluster_label                47432 non-null  object
#  6   class_color                  47432 non-null  object
#  7   class_order                  47432 non-null  float64
#  8   class_label                  47432 non-null  object
#  9   subclass_color               47432 non-null  object
#  10  subclass_order               47432 non-null  float64
#  11  subclass_label               47432 non-null  object
# ...

# %%
file_path_sample_exp = '/Users/tanmaysagarhuria/__MACOSX/FinalProject/sample-exp_component mapping_human_smart-seq_oct_2019.csv'

# %%
sample_exp_df = load_csv(file_path_sample_exp)
# Out:
# Successfully loaded /Users/tanmaysagarhuria/__MACOSX/FinalProject/sample-exp_component mapping_human_smart-seq_oct_2019.csv

# %%
if sample_exp_df is not None:
    print("Sample Exp DataFrame:")
    print(sample_exp_df.info())
    print(sample_exp_df.describe())
    print(sample_exp_df.head())
# Out:
# Sample Exp DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49417 entries, 0 to 49416
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   sample_name         49417 non-null  object
#  1   exp_component_name  49417 non-null  object
# dtypes: object(2)
# memory usage: 772.3+ KB
# None
#                 sample_name   exp_component_name
# count                 49417                49417
# unique                49417                49417
# top     F2S4_160113_027_A01  LS-15005h_S01_E1-50
# freq                      1                    1
#            sample_name   exp_component_name
# 0  F2S4_160113_027_A01  LS-15005h_S01_E1-50
# 1  F2S4_160113_027_B01  LS-15005h_S02_E1-50
# 2  F2S4_160113_027_C01  LS-15005h_S03_E1-50
# 3  F2S4_160113_027_D01  LS-15005h_S04_E1-50
# 4  F2S4_160113_027_E01  LS-15005h_S05_E1-50

# %%
print("Missing values in each column:")
print(matrix_df.isnull().sum())
# Out:
# Missing values in each column:
# sample_name    0
# 3.8-1.2        0
# 3.8-1.3        0
# 3.8-1.4        0
# 3.8-1.5        0
#               ..
# ZYX            0
# ZZEF1          0
# ZZZ3           0
# bA255A11.4     0
# bA395L14.12    0
# Length: 50282, dtype: int64

# %%
import pandas as pd

# %%
transposed_df = matrix_df.set_index('sample_name').transpose().reset_index()

# Rename the columns
transposed_df.rename(columns={'index': 'gene'}, inplace=True)

# Melt the DataFrame to have a long format with an "expression_level" column
melted_df = pd.melt(transposed_df, id_vars=['gene'], var_name='sample_name', value_name='expression_level')

# %%
conda install dask
# Out:
# ...
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# / DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-arm64/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/osx-arm64/current_repodata.json HTTP/1.1" 304 0
# done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# ...

# %%
import dask.dataframe as dd

# %%
import dask.dataframe as dd

# %%
df = dd.read_csv(file_path, sample=1000000)

# %%
import dask.dataframe as dd

# Define the file path for the large CSV file
file_path = '/Users/tanmaysagarhuria/__MACOSX/FinalProject/matrix (1).csv'

# Load the CSV file using Dask with an increased sample size
df = dd.read_csv(file_path, sample=2000000)

# %%
print(df.head())
# Out:
#            sample_name  3.8-1.2  3.8-1.3  3.8-1.4  3.8-1.5  5-HT3C2  A1BG  \
# 0  F2S4_160113_027_A01        0        0        0        0        0     0
# 1  F2S4_160113_027_B01        0        0        0        0        0   118
# 2  F2S4_160113_027_C01        0        0        0        0        0     0
# 3  F2S4_160113_027_D01        0        0        0        0        0   159
# 4  F2S4_160113_027_E01        0        0        0        0        0     1
#
#    A1BG-AS1  A1CF  A2M  ...  ZXDB  ZXDC  ZYG11A  ZYG11AP1  ZYG11B  ZYX  ZZEF1  \
# 0         0     0   41  ...     0   282       0         0       0   41    448
# 1         0     0    0  ...     0   892       0         0     125    0      0
# 2         0     0    0  ...     0     0       1         0     161    0    102
# 3         0     0    0  ...     0   155       1         0      81    0      3
# 4         0     0    1  ...     0    14       1         0     490    0      4
#
#    ZZZ3  bA255A11.4  bA395L14.12
# ...

# %%
print("Sample Exp DataFrame:")
print(sample_exp_df)
# Out:
# Sample Exp DataFrame:
#                sample_name   exp_component_name
# 0      F2S4_160113_027_A01  LS-15005h_S01_E1-50
# 1      F2S4_160113_027_B01  LS-15005h_S02_E1-50
# 2      F2S4_160113_027_C01  LS-15005h_S03_E1-50
# 3      F2S4_160113_027_D01  LS-15005h_S04_E1-50
# 4      F2S4_160113_027_E01  LS-15005h_S05_E1-50
# ...                    ...                  ...
# 49412  F2S4_190227_100_C01  SM-GE4QU_S187_E1-50
# 49413  F2S4_190227_100_E01  SM-GE4QU_S189_E1-50
# 49414  F2S4_190227_100_F01  SM-GE4QU_S190_E1-50
# 49415  F2S4_190227_100_G01  SM-GE4QU_S191_E1-50
# 49416  F2S4_190227_100_H01  SM-GE4QU_S192_E1-50
#
# [49417 rows x 2 columns]

# %%
num_unique_samples = sample_exp_df['sample_name'].nunique()

# %%
print(f'The sample_exp_df DataFrame has {num_unique_samples} unique samples.')
# Out:
# The sample_exp_df DataFrame has 49417 unique samples.

# %%
matrix_samples = set(df['sample_name'].compute())  # Use .compute() because matrix_df is a Dask DataFrame
sample_exp_samples = set(sample_exp_df['sample_name'])

# Find the common samples
common_samples = matrix_samples.intersection(sample_exp_samples)

# Print the number of common samples and the samples themselves
print(f'There are {len(common_samples)} common samples between matrix_df and sample_exp_df.')
print(common_samples)
# Out:
# There are 49417 common samples between matrix_df and sample_exp_df.
# ...

# %%
# Get the unique samples from both DataFrames
matrix_samples = set(df['sample_name'].compute())  # Use .compute() because matrix_df is a Dask DataFrame
sample_exp_samples = set(sample_exp_df['sample_name'])

# Find the common samples
common_samples = matrix_samples.intersection(sample_exp_samples)

# Print the number of common samples and the samples themselves
print(f'There are {len(common_samples)} common samples between matrix_df and sample_exp_df.')
print("Common samples:")
print(common_samples)
# Out:
# There are 49417 common samples between matrix_df and sample_exp_df.
# Common samples:
# ...

# %%
# Compute the unique sample names in matrix_df
unique_matrix_samples = df['sample_name'].nunique().compute()

print(f'The number of unique sample names in matrix_df is: {unique_matrix_samples}')
# Out:
# The number of unique sample names in matrix_df is: 49417

# %%
df = df.rename(columns={'sample_name': 'sample_name'})

# %%
merged_df = dd.merge(df, sample_exp_df, on='sample_name', how='left')

# %%
print(merged_df.head())
# Out:
#            sample_name  3.8-1.2  3.8-1.3  3.8-1.4  3.8-1.5  5-HT3C2  A1BG  \
# 0  F2S4_160113_027_A01        0        0        0        0        0     0
# 1  F2S4_160113_027_B01        0        0        0        0        0   118
# 2  F2S4_160113_027_C01        0        0        0        0        0     0
# 3  F2S4_160113_027_D01        0        0        0        0        0   159
# 4  F2S4_160113_027_E01        0        0        0        0        0     1
#
#    A1BG-AS1  A1CF  A2M  ...  ZXDC  ZYG11A  ZYG11AP1  ZYG11B  ZYX  ZZEF1  ZZZ3  \
# 0         0     0   41  ...   282       0         0       0   41    448     0
# 1         0     0    0  ...   892       0         0     125    0      0   748
# 2         0     0    0  ...     0       1         0     161    0    102     0
# 3         0     0    0  ...   155       1         0      81    0      3     1
# 4         0     0    1  ...    14       1         0     490    0      4    33
#
#    bA255A11.4  bA395L14.12   exp_component_name
# ...

# %%
df = df.rename(columns={'sample_name': 'sample_name'})

# Merge the DataFrames on the 'sample_name' column
matrix_and_sample_df = dd.merge(df, sample_exp_df, on='sample_name', how='left')

# Print the result to verify the merge
print(matrix_and_sample_df.head())
# Out:
#            sample_name  3.8-1.2  3.8-1.3  3.8-1.4  3.8-1.5  5-HT3C2  A1BG  \
# 0  F2S4_160113_027_A01        0        0        0        0        0     0
# 1  F2S4_160113_027_B01        0        0        0        0        0   118
# 2  F2S4_160113_027_C01        0        0        0        0        0     0
# 3  F2S4_160113_027_D01        0        0        0        0        0   159
# 4  F2S4_160113_027_E01        0        0        0        0        0     1
#
#    A1BG-AS1  A1CF  A2M  ...  ZXDC  ZYG11A  ZYG11AP1  ZYG11B  ZYX  ZZEF1  ZZZ3  \
# 0         0     0   41  ...   282       0         0       0   41    448     0
# 1         0     0    0  ...   892       0         0     125    0      0   748
# 2         0     0    0  ...     0       1         0     161    0    102     0
# 3         0     0    0  ...   155       1         0      81    0      3     1
# 4         0     0    1  ...    14       1         0     490    0      4    33
#
#    bA255A11.4  bA395L14.12   exp_component_name
# ...

# %%
import dask.dataframe as dd

# Ensure all column names are strings
matrix_and_sample_df.columns = [str(col) for col in matrix_and_sample_df.columns]

# %%
import bz2
import pandas as pd

# %%
pip install --upgrade pyarrow
# Out:
# ...
#   Obtaining dependency information for pyarrow from https://files.pythonhosted.org/packages/f3/94/4e2a579bbac1adb19e63b054b300f6f7fa04f32f212ce86c18727bdda698/pyarrow-16.1.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.0/26.0 MB 24.6 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 11.0.0
#     Uninstalling pyarrow-11.0.0:
#       Successfully uninstalled pyarrow-11.0.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pandas pyarrow dask
# Out:
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/16/c6/75231fd47afd6b3f89011e7077f1a3958441264aca7ae9ff596e3276a5d0/pandas-2.2.2-cp311-cp311-macosx_11_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for dask from https://files.pythonhosted.org/packages/c6/c7/79f6ae51b64c20db98100946544a47a20671e589be19404f6696481d6024/dask-2024.7.0-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 8.1 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 7.2 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
#   Attempting uninstall: dask
#     Found existing installation: dask 2023.11.0
#     Uninstalling dask-2023.11.0:
#       Successfully uninstalled dask-2023.11.0
# ...

# %%
import dask.dataframe as dd

# Define the file path for the output directory
output_dir_path = '/Users/tanmaysagarhuria/__MACOSX/FinalProject/matrix_and_sample_df_chunks'

# Save the DataFrame in chunks using Dask
dd.to_csv(matrix_and_sample_df, f'{output_dir_path}/part-*.csv', single_file=False, index=False, compression='gzip')

print(f"DataFrame saved in chunks to {output_dir_path}")
# Out:
# DataFrame saved in chunks to /Users/tanmaysagarhuria/__MACOSX/FinalProject/matrix_and_sample_df_chunks
